# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Laptop pricing.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
# 5           5         Dell         3    Full HD    1   1         5
# 6           6           HP         3    Full HD    3   1         5
# 7           7         Acer         3  IPS Panel    2   1         5
# 8           8         Dell         3    Full HD    1   1         5
# 9           9         Acer         3  IPS Panel    3   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# ...

# %%
df.shape
# Out:
# (238, 13)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Category', 'Screen', 'GPU', 'OS',
#        'CPU_core', 'Screen_Size_cm', 'CPU_frequency', 'RAM_GB',
#        'Storage_GB_SSD', 'Weight_kg', 'Price'],
#       dtype='object')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head(5)
# Out:
#   Manufacturer  Category     Screen  GPU  OS  CPU_core  Screen_Size_cm  \
# 0         Acer         4  IPS Panel    2   1         5          35.560
# 1         Dell         3    Full HD    1   1         3          39.624
# 2         Dell         3    Full HD    1   1         7          39.624
# 3         Dell         4  IPS Panel    2   1         5          33.782
# 4           HP         4    Full HD    2   1         7          39.624
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0            1.6       8             256       1.60    978
# 1            2.0       4             256       2.20    634
# 2            2.7       8             256       2.20    946
# 3            1.6       8             128       1.22   1244
# 4            1.8       8             256       1.91    837

# %%
df.Manufacturer.unique()
# Out:
# array(['Acer', 'Dell', 'HP', 'Asus', 'Lenovo', 'Huawei', 'Toshiba', 'MSI',
#        'Razer', 'Samsung', 'Xiaomi'], dtype=object)

# %%
df.Screen.value_counts()
# Out:
# Screen
# Full HD      161
# IPS Panel     77
# Name: count, dtype: int64

# %%
df['Screen'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *   The above pie chart represents the Screen types of laptops

# %%
df['Screen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Screen'>

# %% [markdown]
# *   The above bar graph represents the Screen types of laptops

# %%
df.Category.value_counts()
# Out:
# Category
# 3    154
# 4     60
# 1     14
# 5      9
# 2      1
# Name: count, dtype: int64

# %%
df['Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *   The above pie chart represents the Categories of laptop

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# *   The above bar graph represents the Categories of laptops

# %%
df.Manufacturer.value_counts()
# Out:
# Manufacturer
# Dell       71
# Lenovo     52
# HP         49
# Acer       19
# Asus       18
# Toshiba    17
# Samsung     5
# MSI         4
# Huawei      1
# Razer       1
# Xiaomi      1
# Name: count, dtype: int64

# %%
df['Manufacturer'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *   The above pie chart represents the manufacturing data of the laptop
# *   leading manufacturer is DELL & least manufacturer is XIAOMI

# %%
df['Manufacturer'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Manufacturer'>

# %% [markdown]
# *  The above bar graph represents the manufacturing data of the laptop
#
# *   leading manufacturer is DELL & least manufacturer is XIAOMI

# %%
df['Storage_GB_SSD'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *  The above pie chart represents the storage_GB_SSD data of the laptops
# *   Most of thhe laptops have 256GB storage

# %%
df['Storage_GB_SSD'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Storage_GB_SSD'>

# %% [markdown]
# * The above bar graph represents the storage_GB_SSD data of the laptops
# *   Most of thhe laptops have 256GB storage

# %%
df['Screen'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *   The above pie chart represents the screen data of the laptops
# *   Most of the laptops have FULL HD screen

# %%
df['Screen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Screen'>

# %% [markdown]
# *  The above bar graph represents the screen data of the laptops
# *   Most of the laptops have FULL HD screen

# %%
df['CPU_frequency'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *   The above pie chart represents the CPU_frequency of the laptops
# *  most of the laptops have 2.7 CPU_frequency

# %%
df['CPU_frequency'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='CPU_frequency'>

# %% [markdown]
# *  The above bar graph represents the CPU_frequency of the laptops
#   most of the laptops have 2.7 CPU_frequency
